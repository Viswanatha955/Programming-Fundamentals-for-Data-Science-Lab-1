# %%
##1
print('Hello World')
a = 10
b = 5
# Out:
# Hello World

# %%
 ##2
 #Addition
 print(a, '+', b, '=', a+b)
# Out:
# 10 + 5 = 15

# %%
#Suntraction
 print(a, '-', b, '=', a-b)
# Out:
# 10 - 5 = 5

# %%
 #Multiplication
 print(a, '*', b, '=', a*b)
# Out:
# 10 * 5 = 50

# %%
#Division
print(a, '/', b, '=', a/b)
# Out:
# 10 / 5 = 2.0

# %%
x=int(input('a'))
y=int(input('b'))
z=int((a+b))
print(z)
# Out:
# a5
# b9
# 14

# %%
##3

# %%
import math

# %%
a=int(input('a='))
b=int(input('b='))
c=int(input('c='))

x1=(-b+math.sqrt(b*b-4*a*c))/(2*a)
x2=(-b-math.sqrt(b*b-4*a*c))/(2*a)
print('x1=',x1)
print('x2',x2)
# Out:
# a=2
# b=4
# c=2
# x1= -1.0
# x2 -1.0

# %%
##3.3

# %%
a=int(input('a='))
b=int(input('b='))
c=int(input('c='))

d=b*b-4*a*c
if d >=0:
  x1=(-b+math.sqrt(b*b-4*a*c))/(2*a)
  x2=(-b-math.sqrt(b*b-4*a*c))/(2*a)
  print('x1=',x1)
  print('x2=',x2)
else:
  print('No real solution')
# Out:
# a=5
# b=7
# c=8
# No real solution

# %%
##3.5

# %%
a =int(input('a='))
b = int(input('b='))
c = int(input('c='))

d= b*b-4*a*c
if a==0 or d<0:
  print('Error')
else:
  x1 = (-b+math.aqrt(b*b-4*a*c))/(2*a)
  x2 = (-b-math.sqrt(b*b-4*a*c))/(2*a)
  print('x1=',x1)
  print('x2=',x2)
# Out:
# a=5
# b=8
# c=7
# Error
